# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd

df = pd.read_csv('/Users/jedmurph/Documents/CODE/pandas-challenge-1/Starter_Code/Resources/client_dataset.csv')
df.head(10)
# Out:
#        first      last                                           job  \
# 0     Donald   Harding                                  Immunologist
# 1    Tiffany     Myers                               Music therapist
# 2    Shannon    Watson                                  Immunologist
# 3     Nathan     Baker                         Accounting technician
# 4  Christina  Schwartz                                  Chiropractor
# 5    Jessica     Reyes  Production designer, theatre/television/film
# 6      Brian     Moore                                       Barista
# 7      Jesus    Wright                            Theme park manager
# 8    Rebecca     Brown                                   Chiropodist
# 9       Greg    Garcia                            Secretary, company
#
#                  phone                                email  client_id  \
# 0   793-904-7725x39308     harding.donald.7185@sullivan.com      58515
# ...

# %%
# View the column names in the data
columns_list = df.columns

print(columns_list)
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')

# %%
# Use the describe function to gather some basic statistics

df.describe()
# Out:
#           client_id      order_id    order_week    order_year    unit_price  \
# count  54639.000000  5.463900e+04  54639.000000  54639.000000  54639.000000
# mean   54837.869416  5.470190e+06     11.359139   2022.993064    136.267207
# std    25487.438231  2.599807e+06      7.023499      0.082997    183.873135
# min    10033.000000  1.000886e+06      1.000000   2022.000000      0.010000
# 25%    33593.000000  3.196372e+06      6.000000   2023.000000     20.800000
# 50%    53305.000000  5.496966e+06     11.000000   2023.000000     68.310000
# 75%    78498.000000  7.733869e+06     17.000000   2023.000000    173.160000
# max    99984.000000  9.998480e+06     52.000000   2023.000000   1396.230000
#
#           unit_cost   unit_weight           qty   line_number
# count  54639.000000  54639.000000  5.463900e+04  54639.000000
# mean      99.446073      5.004116  5.702646e+02      2.979667
# std      133.164267      5.326599  1.879552e+04      2.436320
# ...

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.

df.count(axis='columns')
# Out:
# 0        18
# 1        18
# 2        18
# 3        18
# 4        18
#          ..
# 54634    18
# 54635    18
# 54636    18
# 54637    18
# 54638    18
# Length: 54639, dtype: int64

# %%
df.isna().sum()
# Out:
# first          0
# last           0
# job            0
# phone          0
# email          0
# client_id      0
# order_id       0
# order_date     0
# order_week     0
# order_year     0
# item_id        0
# category       0
# subcategory    0
# unit_price     0
# unit_cost      0
# unit_weight    0
# qty            0
# line_number    0
# dtype: int64

# %%
df.dtypes
# Out:
# first           object
# last            object
# job             object
# phone           object
# email           object
# client_id        int64
# order_id         int64
# order_date      object
# order_week       int64
# order_year       int64
# item_id         object
# category        object
# subcategory     object
# unit_price     float64
# unit_cost      float64
# unit_weight    float64
# qty              int64
# line_number      int64
# dtype: object

# %%
df["last"].unique()
# Out:
# array(['Harding', 'Myers', 'Watson', 'Baker', 'Schwartz', 'Reyes',
#        'Moore', 'Wright', 'Brown', 'Garcia', 'Williams', 'Howard',
#        'Gould', 'Taylor', 'Orozco', 'Jordan', 'Green', 'Stephenson',
#        'Anderson', 'Roberts', 'Rhodes', 'Mendoza', 'Lowe', 'Rice', 'Cook',
#        'Kennedy', 'Harris', 'Palmer', 'Robertson', 'Barnes', 'Wells',
#        'Spencer', 'Brooks', 'Mitchell', 'Mccann', 'Bean', 'Griffith',
#        'Wagner', 'Johnson', 'Newman', 'Hernandez', 'Davis', 'Simmons',
#        'Turner', 'Aguilar', 'Kelly', 'Chase', 'Hobbs', 'Wilkinson',
#        'Peterson', 'Cervantes', 'Carlson', 'Thompson', 'Vasquez', 'Ward',
#        'Middleton', 'Arias', 'Ramirez', 'Pennington', 'Ellis', 'Mcmillan',
#        'Morgan', 'Austin', 'Vincent', 'Campbell', 'Richardson', 'Colon',
#        'Jackson', 'Espinoza', 'West', 'Schultz', 'Cannon', 'Hanson',
#        'Gilbert', 'Powell', 'Lewis', 'Bennett', 'Evans', 'Martin',
# ...

# %%
df.value_counts(ascending=False)
# Out:
# first    last       job                             phone                   email                              client_id  order_id  order_date  order_week  order_year  item_id         category     subcategory       unit_price  unit_cost  unit_weight  qty  line_number
# Aaron    Martinez   Armed forces technical officer  283.652.2505x6088       aaron.martinez@morton.biz          19820      2178609   2023-05-01  18          2023        ABX14990-37-1Z  furniture    tables            0.02        0.01       4.22         29   1              1
# Melissa  Smith      Pilot, airline                  001-638-231-7128x99395  smithmelissa@miller.com            99231      2592231   2023-05-21  20          2023        XUB12331-18-1A  consumables  misc              30.40       25.88      2.00         50   4              1
# ...

# %%
total = df.sum()

print(total)
# Out:
# first          DonaldTiffanyShannonNathanChristinaJessicaBria...
# last           HardingMyersWatsonBakerSchwartzReyesMooreWrigh...
# job            ImmunologistMusic therapistImmunologistAccount...
# phone          793-904-7725x39308201.442.4543x942687.737.9424...
# email          harding.donald.7185@sullivan.commyers.t.6537@f...
# client_id                                             2996286347
# order_id                                            298885713037
# order_date     2023-04-282023-05-192023-01-292023-04-252023-0...
# order_week                                                620652
# order_year                                             110534318
# item_id        EUD29711-63-6UXDA18116-89-4AABE59463-05-7EZMM0...
# category       decorconsumablessoftwareconsumablesconsumables...
# subcategory    wall artpensproject managementpensmiscplantski...
# unit_price                                            7445503.92
# ...

# %%
# What three item categories had the most entries?
category = "category"
highest_three_values_in_column = df[category].value_counts().nlargest(3)

print(highest_three_values_in_column)
# Out:
# category
# consumables    23538
# furniture      11915
# software        8400
# Name: count, dtype: int64

# %%
# For the category with the most entries,
# which subcategory had the most entries?
subcategory = "subcategory"


most_common_subcategory = df[subcategory].value_counts().idxmax()

print(most_common_subcategory)
# Out:
# bathroom supplies

# %%
# Which five clients had the most entries in the data?
client_id = "client_id"

top_five_clients = df[client_id].value_counts().nlargest(5)
print(top_five_clients)
# Out:
# client_id
# 33615    220
# 66037    211
# 46820    209
# 38378    207
# 24741    207
# Name: count, dtype: int64

# %%
# Store the client ids of those top 5 clients in a list.

top_five_clients_ids = top_five_clients.index.tolist()
print(top_five_clients_ids)
# Out:
# [33615, 66037, 46820, 38378, 24741]

# %%
# How many total units (the qty column) did the
# client with the most entries order order?
top_client_id = df['client_id'].value_counts().idxmax()

total_units_ordered = df[df['client_id'] == top_client_id]['qty'].sum()

print(total_units_ordered)
# Out:
# 64313

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the 
# subtotal for each line using the unit_price
# and the qty

df["subtotal"] = df["unit_price"] * df["qty"]



df.head(10)
# Out:
#        first      last                                           job  \
# 0     Donald   Harding                                  Immunologist
# 1    Tiffany     Myers                               Music therapist
# 2    Shannon    Watson                                  Immunologist
# 3     Nathan     Baker                         Accounting technician
# 4  Christina  Schwartz                                  Chiropractor
# 5    Jessica     Reyes  Production designer, theatre/television/film
# 6      Brian     Moore                                       Barista
# 7      Jesus    Wright                            Theme park manager
# 8    Rebecca     Brown                                   Chiropodist
# 9       Greg    Garcia                            Secretary, company
#
#                  phone                                email  client_id  \
# 0   793-904-7725x39308     harding.donald.7185@sullivan.com      58515
# ...

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound
# for orders over 50 pounds and $10 per
# pound for items 50 pounds or under.


df['shipping_price'] = df['unit_weight'] * df['qty'].apply(lambda x: 
                                          7 if x > 50 
                                          else 10)

df.head(10)
# Out:
#        first      last                                           job  \
# 0     Donald   Harding                                  Immunologist
# 1    Tiffany     Myers                               Music therapist
# 2    Shannon    Watson                                  Immunologist
# 3     Nathan     Baker                         Accounting technician
# 4  Christina  Schwartz                                  Chiropractor
# 5    Jessica     Reyes  Production designer, theatre/television/film
# 6      Brian     Moore                                       Barista
# 7      Jesus    Wright                            Theme park manager
# 8    Rebecca     Brown                                   Chiropodist
# 9       Greg    Garcia                            Secretary, company
#
#                  phone                                email  client_id  \
# 0   793-904-7725x39308     harding.donald.7185@sullivan.com      58515
# ...

# %%
# Create a column for the total price
# using the subtotal and the shipping price
# along with a sales tax of 9.25%

df["total_price"] = df["subtotal"] + df["shipping_price"] + (df["subtotal"] + df["shipping_price"]) * 0.0925

df.head(10)
# Out:
#        first      last                                           job  \
# 0     Donald   Harding                                  Immunologist
# 1    Tiffany     Myers                               Music therapist
# 2    Shannon    Watson                                  Immunologist
# 3     Nathan     Baker                         Accounting technician
# 4  Christina  Schwartz                                  Chiropractor
# 5    Jessica     Reyes  Production designer, theatre/television/film
# 6      Brian     Moore                                       Barista
# 7      Jesus    Wright                            Theme park manager
# 8    Rebecca     Brown                                   Chiropodist
# 9       Greg    Garcia                            Secretary, company
#
#                  phone                                email  client_id  \
# 0   793-904-7725x39308     harding.donald.7185@sullivan.com      58515
# ...

# %%
# Create a column for the cost
# of each line using unit cost, qty, and
# shipping price (assume the shipping cost
# is exactly what is charged to the client).

df['line_cost'] = (df['unit_cost'] * df['qty']) + (df['shipping_price'] * df['qty'])

df.head(10)
# Out:
#        first      last                                           job  \
# 0     Donald   Harding                                  Immunologist
# 1    Tiffany     Myers                               Music therapist
# 2    Shannon    Watson                                  Immunologist
# 3     Nathan     Baker                         Accounting technician
# 4  Christina  Schwartz                                  Chiropractor
# 5    Jessica     Reyes  Production designer, theatre/television/film
# 6      Brian     Moore                                       Barista
# 7      Jesus    Wright                            Theme park manager
# 8    Rebecca     Brown                                   Chiropodist
# 9       Greg    Garcia                            Secretary, company
#
#                  phone                                email  client_id  \
# 0   793-904-7725x39308     harding.donald.7185@sullivan.com      58515
# ...

# %%
# Create a column for the profit of
# each line using line cost and line price
df["line_profit"] = df["total_price"] - df["line_cost"]

df.head(10)
# Out:
#        first      last                                           job  \
# 0     Donald   Harding                                  Immunologist
# 1    Tiffany     Myers                               Music therapist
# 2    Shannon    Watson                                  Immunologist
# 3     Nathan     Baker                         Accounting technician
# 4  Christina  Schwartz                                  Chiropractor
# 5    Jessica     Reyes  Production designer, theatre/television/film
# 6      Brian     Moore                                       Barista
# 7      Jesus    Wright                            Theme park manager
# 8    Rebecca     Brown                                   Chiropodist
# 9       Greg    Garcia                            Secretary, company
#
#                  phone                                email  client_id  \
# 0   793-904-7725x39308     harding.donald.7185@sullivan.com      58515
# ...

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
# Check your work using the totals above
total_price_per_order = df.groupby("order_id")["total_price"].sum()

order_id_list = [2742071, 2173913, 6128929]
for order_id in order_id_list:
    total_price = total_price_per_order.get(order_id, 0)

    print(f"Total price for order_id {order_id}: ${total_price:.2f}")
# Out:
# Total price for order_id 2742071: $139801.71
# Total price for order_id 2173913: $119793.39
# Total price for order_id 6128929: $752665.99

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
# How much did each of the top 5 clients by quantity
# spend? Check your work from Part 1 for client ids.
df["total_spent"] = df["qty"] * df["unit_price"]
client_spending = df.groupby("client_id")["total_spent"].sum()


for client_id in top_five_clients.index:
    client_total_spending = client_spending.loc[client_id]
    print(f"Client ID {client_id} spent: ${client_total_spending:.2f}")
# Out:
# Client ID 33615 spent: $5839032.11
# Client ID 66037 spent: $7995708.38
# Client ID 46820 spent: $7317356.03
# Client ID 38378 spent: $8384321.15
# Client ID 24741 spent: $70176885.25

# %%
# Create a summary DataFrame showing the totals for the
# for the top 5 clients with the following information:
# total units purchased, total shipping price,
# total revenue, and total profit. Sort by total profit.

df["total_units_purchased"] = df["qty"].groupby(df["client_id"]).sum()
df["total_shipping_price"] = df["shipping_price"].groupby(df["client_id"]).sum()
df["total_revenue"] = df["total_spent"].groupby(df["client_id"]).sum()
df["total_profit"] = df["total_revenue"] - df["total_shipping_price"]

top_five_clients_summary = df.groupby("client_id").agg(
    total_units_purchased=("total_units_purchased", "sum"),
    total_shipping_price=("total_shipping_price", "sum"),
    total_revenue=("total_revenue", "sum"),
    total_profit=("total_profit", "sum")
).sort_values(by="total_profit", ascending=False).head(5)

df.head(10)
# Out:
#        first      last                                           job  \
# 0     Donald   Harding                                  Immunologist
# 1    Tiffany     Myers                               Music therapist
# 2    Shannon    Watson                                  Immunologist
# 3     Nathan     Baker                         Accounting technician
# 4  Christina  Schwartz                                  Chiropractor
# 5    Jessica     Reyes  Production designer, theatre/television/film
# 6      Brian     Moore                                       Barista
# 7      Jesus    Wright                            Theme park manager
# 8    Rebecca     Brown                                   Chiropodist
# 9       Greg    Garcia                            Secretary, company
#
#                  phone                                email  client_id  \
# 0   793-904-7725x39308     harding.donald.7185@sullivan.com      58515
# ...

# %%
# Format the data and rename the columns
# to names suitable for presentation.
# Currency should be in millions of dollars.

columns_list_renamed = columns_list.rename(columns={
    "client_id": "Client ID",
    "order_id": "Order ID",
    "order_date": "Order Date",
    "order_week": "Order Week",
    "order_year": "Order Year",
    "subtotal": "Subtotal",
    "total_units_purchased": "Total Units",
    "total_shipping_price": "Total Shipping Price",
    "total_revenue": "Total Revenue",
    "total_profit": "Total Profit"
})

columns_list_renamed["Total Revenue"] = columns_list_renamed["Total Revenue"] / 1000000
columns_list_renamed["Total Profit"] = columns_list_renamed["Total Profit"] / 1000000
columns_list_renamed["Total Shipping Price"] = columns_list_renamed["Total Shipping Price"] / 1000000
df.head(5)
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ...   subtotal shipping_price    total_price  \
# ...

# %%
# Sort the updated data by "Total Profit" form highest to lowest
# Out:
#    Client ID   Units Shipping Total Revenue Total Cost Total Profit
# 4      24741  239862   $5.13M       $82.27M    $45.69M      $36.58M
# 3      38378   73667   $3.43M       $12.91M     $9.63M       $3.27M
# 1      66037   43018   $1.40M       $10.26M     $7.00M       $3.26M
# 2      46820   75768   $1.60M        $9.74M     $7.01M       $2.74M
# 0      33615   64313   $1.83M        $8.38M     $6.18M       $2.20M

# %%
"Total Profit" = False
# Out:
#   Cell In[79], line 1
#     "Total Profit" = False
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?
